# %%
# !pip install requests

# %%
url1 = 'https://maps.googleapis.com/maps/api/geocode/json'

response1 = requests.get(
    url1,
    params={
        'address':'津福駅',
        'key':'AIzaSyBjpAeD9Ttqvq-pAK8AUonj6h35wXQZ6fQ'
    }
)

info1 = response1.json()
pprint.pprint(info1)
location = info1['results'][0]['geometry']['location']
lat = location['lat']
lng = location['lng']

url2 = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json'

response2 = requests.get(
    url2,
    params={
        'location':f'{lat},{lng}',
        'language':'ja',
        'radius':500,
        'type':'restaurant',
        'key': 'AIzaSyBjpAeD9Ttqvq-pAK8AUonj6h35wXQZ6fQ'
    }
)

info2 =response2.json()

restaurantInfo = info2['results']

pprint.pprint(restaurantInfo)
# Out:
# {'results': [{'address_components': [{'long_name': 'Tsubuku Station',
#                                       'short_name': 'Tsubuku Station',
#                                       'types': ['establishment',
#                                                 'point_of_interest',
#                                                 'train_station',
#                                                 'transit_station']},
#                                      {'long_name': 'Tsubukuhonmachi',
#                                       'short_name': 'Tsubukuhonmachi',
#                                       'types': ['political',
#                                                 'sublocality',
#                                                 'sublocality_level_2']},
#                                      {'long_name': 'Kurume',
#                                       'short_name': 'Kurume',
#                                       'types': ['locality', 'political']},
# ...

# %%
import requests
import pprint
from getpass import getpass

api_key = getpass('APIキーを入力してください：')
station_search = input('駅名を入力してください：')

url1 = 'https://maps.googleapis.com/maps/api/geocode/json'

response1 = requests.get(
    url1,
    params={
        'address':station_search,
        'key':api_key
    }
)

info1 = response1.json()
location = info1['results'][0]['geometry']['location']
lat = location['lat']
lng = location['lng']

url2 = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json'

response2 = requests.get(
    url2,
    params={
        'location':f'{lat},{lng}',
        'language':'ja',
        'radius':500,
        'type':'restaurant',
        'key': api_key
    }
)

info2 =response2.json()
restaurantInfo = info2['results']

for r in restaurantInfo:
  print(f"駅名：{r.get('name')}")
  print(f"評価：{r.get('rating')}")
  print(f"住所：{r.get('vicinity')}")
# Out:
# APIキーを入力してください：··········
# 駅名を入力してください：津福駅
# 駅名：ハンバーグオニオン 津福店
# 評価：4.1
# 住所：久留米市津福今町４２３−１
# 駅名：海鮮居酒屋 夢邸（ゆめやしき）
# 評価：4.3
# 住所：久留米市津福本町１５６２−１
# 駅名：どんどん亭 津福店
# 評価：3.5
# 住所：久留米市津福本町774?3
# 駅名：カラオケ コロッケ倶楽部 久留米津福店
# 評価：3.7
# 住所：久留米市津福本町１７９３
# 駅名：なつ吉
# 評価：4.3
# 住所：久留米市津福本町１６４４−１
# 駅名：居酒屋きらく
# 評価：None
# 住所：久留米市津福本町１５９３
# 駅名：麺飯酒場 心や食堂(しんやしょくどう)
# 評価：4
# 住所：久留米市津福本町１６４５−５
# 駅名：ありがとう
# 評価：4.1
# 住所：久留米市津福本町１５６２
# 駅名：チェリー
# 評価：4.5
# 住所：久留米市津福本町１６４２−１
# 駅名：やきとり 九十九 津福店（つくも）
# 評価：4.2
# 住所：久留米市津福本町１６４６−２ 津福ビル
# 駅名：一歩
# 評価：4.6
# 住所：久留米市津福本町１５６２−１
# 駅名：酒処 まるたや
# 評価：4.4
# 住所：久留米市津福本町１５６５−１
# 駅名：居酒屋独楽
# 評価：2
# 住所：久留米市津福本町１６４９−４４
# 駅名：とりから家
# 評価：4.5
# 住所：久留米市津福本町１７７９−４
# 駅名：お食事処 更科うどん 津福店
# 評価：4.5
# 住所：久留米市津福本町１４４１−１
# 駅名：スタミナ鉄板ウルトラマン
# 評価：4.1
# 住所：久留米市津福本町１７７９−５０
# 駅名：焼き鳥 道楽燕
# 評価：4.7
# 住所：久留米市津福本町１７１１
# 駅名：ほっともっと 久留米津福店
# 評価：3.5
# 住所：久留米市津福今町４２１−２
# 駅名：まつばラーメン
# 評価：4.2
# 住所：久留米市津福今町４５７−７
# 駅名：DECOSUSHI （デコ寿司）
# 評価：4.3
# 住所：久留米市津福本町１７１９−６
